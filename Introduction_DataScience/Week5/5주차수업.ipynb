# %%
# import requests
# from bs4 import BeautifulSoup

# # for i in range(1,11):
# url  = "https://www.hollys.co.kr/store/korea/korStore2.do?pageNo=1"


# response = requests.get(url)
# # print(requests.get(url).text)
# soup = BeautifulSoup(response.text, 'html.parser')
# print(soup)

# #soup에는 구문분석이 완료된 애들 웹페이지 내용이 저장됨
# # 클래스가 center_t인 td요소 찾기

# td_elements = soup.find_all('td', class_='center_t')
# print(td_elements)

# for td in td_elements:
#   text = td.get_text(strip = True)
#   print(text)


# for x, td in enumerate(td_elements):
#     rest = x % 6
#     if rest == 3 or rest == 5:
#         text = td.get_text(strip=True)
#         print(text)











import requests
from bs4 import BeautifulSoup

# for i in range(1,11):
url  = "https://github.com/search?q=print&type=repositories"


response = requests.get(url)
print(response.text)
soup = BeautifulSoup(response.text, 'html.parser')
print(soup)


#soup에는 구문분석이 완료된 애들 웹페이지 내용이 저장됨
# 클래스가 center_t인 td요소 찾기

# td_elements = soup.find_all('h2', class_='hide-sm hide-md f5 mb-1 color-border-muted')
# print('td_elements=',td_elements)

# for td in td_elements:
#   print(td)
#   text = td.get_text(strip = True)
#   print('text='+text)

# for x, td in enumerate(td_elements):
#     rest = x % 6
#     if rest == 3 or rest == 5:
#         text = td.get_text(strip=True)
#         print(text)






from bs4 import BeautifulSoup

html = '<td id="td1" class="title">' \
       '  <div class="tit3">' \
       '    <a href="/movie/bi/mi/basic.nhn?code=161242" title="범죄도시">범죄도시</a>' \
       '  </div>' \
       '</td>'

# 1. 조회
def ex1():
    # 위의 html 문자열에 대해서, html 파싱하겠다.
    bs = BeautifulSoup(html, 'html.parser')
    print(bs, type(bs))
    # <td id="td1" class="title"><div class="tit3"><a href="/movie/bi/mi/basic.nhn?code=161242" title="범죄도시">범죄도시</a></div></td> <class 'bs4.BeautifulSoup'>

    # a 태그 출력
    tag = bs.a
    print(tag, type(tag))
    # <a href="/movie/bi/mi/basic.nhn?code=161242" title="범죄도시">범죄도시</a> <class 'bs4.element.Tag'>

ex1()
# Out:
# {"payload":{"header_redesign_enabled":false,"results":[{"id":"7386799","archived":false,"color":"#3572A5","followers":7980,"has_funding_file":true,"hl_name":"OctoPrint/Octo<em>Print</em>","hl_trunc_description":"OctoPrint is the snappy web interface for your 3D printer!","language":"Python","mirror":false,"owned_by_organization":true,"public":true,"repo":{"repository":{"id":7386799,"name":"OctoPrint","owner_id":5982294,"owner_login":"OctoPrint","updated_at":"2024-04-04T15:55:43.339Z","has_issues":true}},"sponsorable":false,"topics":["python","raspberry-pi","octoprint","3d-printer"],"type":"Public","help_wanted_issues_count":0,"good_first_issue_issues_count":0,"starred_by_current_user":false},{"id":"751008707","archived":false,"color":"#3572A5","followers":9301,"has_funding_file":true,"hl_name":"FujiwaraChoki/Money<em>Printer</em>","hl_trunc_description":"Automate Creation of YouTube Shorts using MoviePy.","language":"Python","mirror":false,"owned_by_organization":false,"public":true,
# ...
